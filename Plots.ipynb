# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# from matplotlib import cm
# import copy
# import segyio
# from mpl_toolkits.axes_grid1 import make_axes_locatable
# import matlab.engine

# %%
from ukpgks.rss import read_rssdata
from ukpgks.plots import plot_picks
from ukpgks.segy import read_segy
from ukpgks.segy import recip_segy
from ukpgks.segy import write_segy

# %%
perfect,h1 = read_segy('perfect.sgy',coors=True)
real,h2 = read_segy('real.sgy',coors=True)
h = h1['groupX'].values - h2['groupX'].values
plt.rcParams["font.weight"] = "bold"
plt.rcParams["axes.labelweight"] = "bold"
plt.rcParams.update({'font.size': 16})
fig, axs = plt.subplots(2, 1,figsize=(14,12),gridspec_kw={'height_ratios': [3, 1]})
axs[0].plot(perfect,'.r')
axs[0].plot(real,'.g')
axs[0].set_xlabel('traces')
axs[0].set_ylabel('TWT')
axs[0].set_ylim(15,2)
axs[1].plot(perfect-real,'.r')
axs[1].set_ylabel('TWT difference')
axs[0].set_ylabel('traces')
# Out:
# Text(0, 0.5, 'traces')
